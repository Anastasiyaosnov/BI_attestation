# %% [markdown]
# #Подготовка

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file = '/content/Премиум авто_рабоча.xlsx'

# %%
xl = pd.ExcelFile(file)

# %%
print(xl.sheet_names)
# Out:
# ['Справочник', 'Маркетинговые данные', 'Данные из CRM']

# %%
spravochnik_df = xl.parse('Справочник')

# %%
marketing_df=xl.parse('Маркетинговые данные')

# %%
crm_df=xl.parse('Данные из CRM')

# %%
spravochnik_df
# Out:
#        Марка  Модель          Цена      Валюта  Маржинальность
# 0   Mercedes     gls  1.135135e+05  Доллар США            0.33
# 1   Mercedes  GT_AMG  1.743243e+05  Доллар США            0.34
# 2        BMW      x5  7.222222e+04        Евро            0.27
# 3        BMW      i3  5.166667e+04        Евро            0.35
# 4   Mercedes    с180  2.300000e+06       Рубль            0.20
# 5   Mercedes    e220  3.850000e+06       Рубль            0.21
# 6        BMW      x1  2.200000e+06       Рубль            0.22
# 7        BMW      x3  3.350000e+06       Рубль            0.23
# 8   Mercedes    c200  2.750000e+06       Рубль            0.24
# 9        BMW     318  2.100000e+06       Рубль            0.25
# 10       BMW    530d  5.300000e+06       Рубль            0.26
# 11  Mercedes    e400  5.900000e+06       Рубль            0.28
# 12  Mercedes     GLE  7.200000e+06       Рубль            0.29
# 13  Mercedes     cla  2.050000e+06       Рубль            0.30
# ...

# %%
marketing_df
# Out:
#                          Client ID                   Domain     Марка  \
# 0      GA1.2.1029165320.1581675414       BMW-keyauto-krd.ru       BMW
# 1      GA1.2.1029165320.1581675414  cars.BMW-keyauto-krd.ru       BMW
# 2      GA1.2.1029165320.1581675414       BMW-keyauto-krd.ru       BMW
# 3       GA1.2.360702973.1573932024       BMW-keyauto-krd.ru       BMW
# 4      GA1.2.1394084210.1579796276    Mersedes-krasnodar.ru  Mercedes
# ...                            ...                      ...       ...
# 66157   GA1.2.719597775.1578814255       BMW-keyauto-krd.ru       BMW
# 66158  GA1.2.1787735095.1578381366    Mersedes-krasnodar.ru  Mercedes
# 66159  GA1.2.1994191491.1578813741    Mersedes-krasnodar.ru  Mercedes
# 66160    GA1.2.83095213.1578206594    Mersedes-krasnodar.ru  Mercedes
# 66161  GA1.2.1866392047.1579068850    Mersedes-krasnodar.ru  Mercedes
#
#             City     Region    Browser Device Category                Date  \
# ...

# %%
crm_df
# Out:
#                          Client ID             Город Просчет стоимости модели  \
# 0      GA1.2.1108606219.1572272784         Krasnodar                      NaN
# 1       GA1.2.125017234.1571028033         Krasnodar                        0
# 2      GA1.2.1823974094.1570697747         Krasnodar                        -
# 3      GA1.2.1823974094.1570697747         Krasnodar                        0
# 4       GA1.2.554197778.1572516039         Krasnodar                      NaN
# ...                            ...               ...                      ...
# 66157   GA1.2.809073096.1580964660          Voronezh                        1
# 66158   GA1.2.914030393.1581675332  Saint Petersburg                        -
# 66159   GA1.2.930162724.1578985942          Voronezh                        -
# 66160   GA1.2.945678631.1572467756       Vladikavkaz                        -
# 66161   GA1.2.967288142.1581838503            Samara                        -
#
#       Приход к диллеру Продажа
# ...

# %% [markdown]
# #Задача 1. Из каких регионов больше всего заявок

# %%
max_conversion_by_city = marketing_df.groupby('Region')['Конверсия'].sum().sort_values(ascending=False)

# %%
max_conversion_by_city.head(3)
# Out:
# Region
# Krasnodar Krai    23849
# Stavropol Krai     1642
# Rostov Oblast      1160
# Name: Конверсия, dtype: int64

# %% [markdown]
# ***Решение задачи 1: Krasnodar Krai, Stavropol Krai, Rostov Oblast***

# %% [markdown]
# #Задача 2. Какой средний процент отказов (Bounce)

# %%
marketing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66162 entries, 0 to 66161
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client ID                 66162 non-null  object
#  1   Domain                    66162 non-null  object
#  2   Марка                     66162 non-null  object
#  3   City                      66162 non-null  object
#  4   Region                    66162 non-null  object
#  5   Browser                   66162 non-null  object
#  6   Device Category           66162 non-null  object
#  7   Date                      66162 non-null  object
#  8   Pageviews                 66162 non-null  int64
#  9   Campaign                  66162 non-null  object
#  10  Keyword                   64710 non-null  object
#  11  Medium                    66162 non-null  object
#  12  Source                    66162 non-null  object
# ...

# %%
marketing_df['Bounce Rate']=marketing_df['Bounce Rate'].replace('-', 0)

# %%
marketing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66162 entries, 0 to 66161
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client ID                 66162 non-null  object
#  1   Domain                    66162 non-null  object
#  2   Марка                     66162 non-null  object
#  3   City                      66162 non-null  object
#  4   Region                    66162 non-null  object
#  5   Browser                   66162 non-null  object
#  6   Device Category           66162 non-null  object
#  7   Date                      66162 non-null  object
#  8   Pageviews                 66162 non-null  int64
#  9   Campaign                  66162 non-null  object
#  10  Keyword                   64710 non-null  object
#  11  Medium                    66162 non-null  object
#  12  Source                    66162 non-null  object
# ...

# %%
avg_bounce = marketing_df['Bounce Rate'].mean()*100

# %%
round(avg_bounce,2)
# Out:
# 0.23

# %% [markdown]
# ***Решение задачи 2: 0,23***

# %% [markdown]
# #Задача 3. С каких устройств чаще заходят на сайты

# %%
max_device = marketing_df['Device Category'].value_counts().head(1)

# %%
max_device
# Out:
# mobile    39465
# Name: Device Category, dtype: int64

# %% [markdown]
# ***Решение задачи 3: mobile***

# %% [markdown]
# # Задача 4.Какие источники наиболее конвертируемые

# %%
max_conversion_by_source = marketing_df.groupby('Source')['Конверсия'].sum().sort_values(ascending=False)

# %%
max_conversion_by_source.head(3)
# Out:
# Source
# google       9106
# yandex.ru    5668
# yandex       5035
# Name: Конверсия, dtype: int64

# %% [markdown]
# ***Решение задачи 4: google, yandex.ru, yandex***
